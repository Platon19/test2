# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(-10,10,1000)
y=np.arctan(x)#+0.05*np.random.randn(1000)
y1=np.arctan(2*x-4)
plt.figure(figsize=(18,4))
plt.plot(x,y)
plt.plot(x,y1)
plt.show()
