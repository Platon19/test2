# %%
import numpy as np
import scipy.integrate as integrate
import scipy.special as special
import matplotlib.pyplot as plt
import cmath

# %%
def Cauchy(z):
    #eps=1e-10
    #s=integrate.quad(lambda x: np.exp(-x**2)/(x-z), -np.inf, z.real-eps)[0]
    #s=s+integrate.quad(lambda x: np.exp(-x**2)/(x-z), z.real+eps,  np.inf)[0]
    return -2*special.dawsn(z)#s/np.sqrt(np.pi)
I = np.vectorize(Cauchy)

# %%
x=np.linspace(-15,15, 200)
y=I(x)
#y1=-2*special.dawsn(x)
plt.plot(x,y,color='blue',lw=1)
#plt.plot(x,y1,color='red',lw=1)
plt.show()

# %%
def lambda_x(w, v):
    B=2/v**2
    A=1-1j*w/v
    z=np.linspace(-15,15, 200)
    y=((1-(B*z**2)/A**2-z*B*(z**2-A/B)*I(z)/A**2)).real
    plt.plot(z,y,color='red',lw=1)
    plt.show()

# %%
lambda_x(0.1,0.05)

# %%
def Cauchy1(z):
    s=integrate.quad(lambda x: (x-z.real)*np.exp(-x**2)/((x-z.real)**2+z.imag**2), -np.inf, np.inf)[0]
    s=s+1j*z.imag*integrate.quad(lambda x: np.exp(-x**2)/((x-z.real)**2+z.imag**2), -np.inf, np.inf)[0]
    return s/np.sqrt(np.pi)
I1 = np.vectorize(Cauchy1)
def lambda_z_plus(w, v):
    B=2/v**2
    A=1-1j*w/v
    print('lambda_inf=',(1-1/A+1/(A*v)**2).real)
    z=np.linspace(0,15, 200)+0.0001j
    y=(1-(B*z**2)/A**2-z*B*(z**2-A/B)*I1(z)/A**2).real
    plt.plot(z.real,y,color='blue',lw=1)
    z=np.linspace(-15,0, 200)-0.0001j
    y=(1-(B*z**2)/A**2-z*B*(z**2-A/B)*I1(z)/A**2).real
    plt.plot(z.real,y,color='blue',lw=1)
    plt.show()

# %%
lambda_z_plus(0.1,0.05)
# Out:
# lambda_inf= -47.199999999999996

# %%
def Cauchy1(z):
    s=integrate.quad(lambda x: (x-z.real)*np.exp(-x**2)/((x-z.real)**2+z.imag**2), -np.inf, np.inf)[0]
    s=s+1j*z.imag*integrate.quad(lambda x: np.exp(-x**2)/((x-z.real)**2+z.imag**2), -np.inf, np.inf)[0]
    return s/np.sqrt(np.pi)
I1 = np.vectorize(Cauchy1)
def lambda_z_minus(w, v):
    B=2/v**2
    A=1-1j*w/v
    z=np.linspace(0,15, 200)-0.0001j
    y=(1-(B*z**2)/A**2-z*B*(z**2-A/B)*I1(z)/A**2).real
    plt.plot(z.real,y,color='blue',lw=1)
    z=np.linspace(-15,0, 200)+0.0001j
    y=(1-(B*z**2)/A**2-z*B*(z**2-A/B)*I1(z)/A**2).real
    plt.plot(z.real,y,color='blue',lw=1)
    plt.show()

# %%
lambda_z_minus(0.1,0.05)

# %%
def Cauchy1(z):
    s=integrate.quad(lambda x: (x-z.real)*np.exp(-x**2)/((x-z.real)**2+z.imag**2), -np.inf, np.inf)[0]
    s=s+1j*z.imag*integrate.quad(lambda x: np.exp(-x**2)/((x-z.real)**2+z.imag**2), -np.inf, np.inf)[0]
    return s/np.sqrt(np.pi)
I1 = np.vectorize(Cauchy1)
def lambda_z_plus(w, v):
    B=2/v**2
    A=1-1j*w/v
    z=np.linspace(0,15, 200)-0.0001j
    y=(1-(B*z**2)/A**2-z*B*(z**2-A/B)*I1(z)/A**2).real+(1-(B*(z+0.0002j)**2)/A**2-(z+0.0002j)*B*((z+0.0002j)**2-A/B)*I1(z+0.0002j)/A**2).real
    plt.plot(z.real,y/2,color='blue',lw=1)
    z=np.linspace(-15,0, 200)+0.0001j
    y=(1-(B*z**2)/A**2-z*B*(z**2-A/B)*I1(z)/A**2).real+(1-(B*(z-0.0002j)**2)/A**2-(z-0.0002j)*B*((z-0.0002j)**2-A/B)*I1(z-0.0002j)/A**2).real
    plt.plot(z.real,y/2,color='blue',lw=1)
    lambda_x(0.1,0.05)
    plt.show()

# %%
lambda_z_plus(0.1,0.05)

# %%
def Cauchy2(z):
    s=integrate.quad(lambda x: (x**2+z.real**2-z.imag**2-2*x*z.real)*np.exp(-x**2)/((x-z.real)**2+z.imag**2)**2, -np.inf, np.inf)[0]
    s=s+2j*z.imag*integrate.quad(lambda x: (x-z.real)*np.exp(-x**2)/((x-z.real)**2+z.imag**2)**2, -np.inf, np.inf)[0]
    return s/np.sqrt(np.pi)
J=np.vectorize(Cauchy2)
def Cauchy1(z):
    s=integrate.quad(lambda x: (x-z.real)*np.exp(-x**2)/((x-z.real)**2+z.imag**2), -np.inf, np.inf)[0]
    s=s+1j*z.imag*integrate.quad(lambda x: np.exp(-x**2)/((x-z.real)**2+z.imag**2), -np.inf, np.inf)[0]
    return s/np.sqrt(np.pi)
I = np.vectorize(Cauchy1)
def lambda_z(w, v, z):
    B=2/v**2
    A=1-1j*w/v
    return (1-(B*z**2)/A**2-z*B*(z**2-A/B)*I(z)/A**2)
def dlambda_dz(w, v, z):
    B=2/v**2
    A=1-1j*w/v
    return -2*B*z/A**2-B*(3*z**2-A/B)*I(z)/A**2-B*z*(z**2-A/B)*J(z)/A**2

# %%
def root(w,v,x1):
   eps=1e-10
   x2=0
   while abs(x1-x2)>eps:
      s=x1-lambda_z(w, v, x1)/dlambda_dz(w, v, x1)
      x2=x1
      x1=s
   return x1
root=np.vectorize(root)

# %%
print(lambda_z(0.5,0.001,root(0.5,0.001,0.0028-1.27j)))
root(0.8,0.001,0.0028-1.27j)
# Out:
# (-2.220446049250313e-16+3.447762908503904e-17j)
# array(0.00335375-1.45334366j)

# %%
v=0.01
x1=0.0028-1.27j
w=np.linspace(0.1, 0.9, 25)
z=root(w,v,x1)
print(z)
plt.xlim(0,0.1)
plt.plot(z.real,z.imag,color='blue',lw=1)
plt.show()
# Out:
# [-0.00757515+0.07551119j -0.00777493+0.1030642j  -0.00799413+0.13198913j
#  -0.00823547+0.16241669j -0.00850217+0.19449636j -0.00879809+0.22840009j
#  -0.00912791+0.26432696j -0.00949734+0.30250894j -0.00991339+0.34321846j
#  -0.0103848 +0.38677806j  0.01092259-0.43357313j  0.01154079-0.48406885j
#   0.01225761-0.53883317j  0.01309698-0.59856846j  0.01409107-0.66415609j
#   0.01528396-0.73672074j  0.01673763-0.8177256j   0.01854188-0.90911802j
#   0.02083136-1.0135605j   0.02381679-1.13481379j  0.02784552-1.2784073j
#   0.03352944-1.45289362j  0.0420439 -1.67240606j  0.05593194-1.96250495j
#   0.08174519-2.37588517j]

# %%
def Cauchy1(z):
    #s=integrate.quad(lambda x: (x-z.real)*np.exp(-x**2)/((x-z.real)**2+z.imag**2), -np.inf, np.inf)[0]
    #s=s+1j*z.imag*integrate.quad(lambda x: np.exp(-x**2)/((x-z.real)**2+z.imag**2), -np.inf, np.inf)[0]
    return -2*special.dawsn(z) # s/np.sqrt(np.pi)
I1 = np.vectorize(Cauchy1)
def lambda_z_plus(w, v, z):
    B=2/v**2
    A=1-1j*w/v
    return (1-(B*z**2)/A**2-z*B*(z**2-A/B)*I1(z)/A**2)-np.sqrt(np.pi)*1j*z*B*(z**2-A/B)*np.exp(-z**2)/A**2
def lambda_z_minus(w, v, z):
    B=2/v**2
    A=1-1j*w/v
    return (1-(B*z**2)/A**2-z*B*(z**2-A/B)*I1(z)/A**2)+np.sqrt(np.pi)*1j*z*B*(z**2-A/B)*np.exp(-z**2)/A**2
def Gamma(w, v, z):
    s=1j*integrate.quad(lambda x: (x-z.real)*(2*cmath.phase(x+1j)-2*cmath.phase(x-1j)+cmath.phase(lambda_z_plus(w,v,x))-cmath.phase(lambda_z_minus(w,v,x)))/((x-z.real)**2+z.imag**2), -np.inf, np.inf)[0]
    s=s-z.imag*integrate.quad(lambda x: (2*cmath.phase(x+1j)-2*cmath.phase(x-1j)+cmath.phase(lambda_z_plus(w,v,x))-cmath.phase(lambda_z_minus(w,v,x)))/((x-z.real)**2+z.imag**2), -np.inf, np.inf)[0]
    return s/(2*np.pi*1j)
gamma=np.vectorize(Gamma)
lambda_z_minus=np.vectorize(lambda_z_minus)
lambda_z_plus=np.vectorize(lambda_z_plus)

# %%
def fi(z):
    return cmath.phase(z)
fi=np.vectorize(fi)

# %%
w=0.5
v=0.001
def y(w,v,t):
    return cmath.log((((t+1j)/(t-1j))**2)*lambda_z_plus(w, v, t)/lambda_z_minus(w, v, t)).imag
y=np.vectorize(y)
x=np.linspace(-15, 15,  1000)
plt.plot(x,y(w,v,x))

# %% [markdown]
# строим подынтегральную в z=i

# %%
w=0.5
v=0.001
def subintegrative(x,z,w,v):
    if -np.pi<=x<=np.pi:
        y=(2*fi(x+1j)-2*fi(x-1j)+fi(lambda_z_plus(w,v,x))-fi(lambda_z_minus(w,v,x)))/((x-z.real)**2+z.imag**2)
    elif -np.pi>x:
        y=(2*fi(x+1j)-2*fi(x-1j)+fi(lambda_z_plus(w,v,x))-fi(lambda_z_minus(w,v,x))-2*np.pi)/((x-z.real)**2+z.imag**2)
    elif x>np.pi:
        y=(2*fi(x+1j)-2*fi(x-1j)+fi(lambda_z_plus(w,v,x))-fi(lambda_z_minus(w,v,x))+2*np.pi)/((x-z.real)**2+z.imag**2)
    return y
y=np.vectorize(subintegrative)
x=np.linspace(-15, 15,  1000)
plt.plot(x,y(x,1j,w,v))
#plt.xlim(-np.pi-0.1,np.pi+0.1)
plt.show()

# %%
def Gamma(w, v, z):
    s=1j*integrate.quad(lambda x: (x-z.real)*y(x,z,w,v), -np.inf, np.inf)[0]
    s=s-z.imag*integrate.quad(lambda x: y(x,z,w,v), -np.inf, np.inf)[0]
    return s/(2*np.pi*1j)
gamma=np.vectorize(Gamma)
gamma(0.5, 0.001,0.01j)
#lambda_z(0.5,0.001,100+1j)
# Out:
# array(0.15740413+3.14159265j)

# %%
def root(w, v, z):
    B=2/v**2
    A=1-1j*w/v
    lambda_inf=1-1/A+1/(A*v)**2
    #print(lambda_inf)
    return -1j*cmath.sqrt(z**2-(lambda_z(w,v,z)*(z+1j)**2)/(cmath.exp(gamma(w,v,z))*lambda_inf))
root=np.vectorize(root)

# %% [markdown]
# 0.00122578-0.53887075j

# %%
gamma(0.5, 0.001, 0.01j)
# Out:
# array(0.15740413+3.14159265j)

# %%
root(0.5, 0.01, 0.001j)
# Out:
# C:\Users\tanya\AppData\Local\Temp\ipykernel_2668\1906134404.py:2: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   s=1j*integrate.quad(lambda x: (x-z.real)*y(x,z,w,v), -np.inf, np.inf)[0]
# array(0.01464952-0.62826647j)

# %%
lambda_z(0.1, 0.001, root(0.1, 0.001, 0.1j))
# Out:
# C:\Users\tanya\AppData\Local\Temp\ipykernel_2668\1906134404.py:2: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   s=1j*integrate.quad(lambda x: (x-z.real)*y(x,z,w,v), -np.inf, np.inf)[0]
# (3.9405506081397976-0.7446959037235423j)

# %%
v=0.001
x1=0.001j
w=np.linspace(0.1, 1.5, 10)
z=root(w,v,x1)
#print(z)
#plt.xlim(0,0.1)
plt.plot(z.real,z.imag,color='blue',lw=1)
plt.show()
# Out:
# C:\Users\tanya\AppData\Local\Temp\ipykernel_13464\1906134404.py:2: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   s=1j*integrate.quad(lambda x: (x-z.real)*y(x,z,w,v), -np.inf, np.inf)[0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 4
#       2 x1=0.001j
#       3 w=np.linspace(0.1, 1.5, 10)
# ----> 4 z=root(w,v,x1)
#       5 #print(z)
#       6 #plt.xlim(0,0.1)
#       7 plt.plot(z.real,z.imag,color='blue',lw=1)
#
# ...

# %%
z
# Out:
# array([ 8.40049383e-04-8.36278711e-02j,  9.05705033e-04-2.23824973e-01j,
#         1.07647215e-03-4.02015378e-01j,  1.41151575e-03-6.47332843e-01j,
#         2.23158633e-03-1.04365692e+00j,  5.95972239e-03-1.95365257e+00j,
#         4.57036832e+00-3.04184130e-02j,  3.14159241e+00-1.87666402e-03j,
#         3.14159296e+00-2.80534329e-04j, -3.14159296e+00-2.07587945e-04j])

# %%
for i in range(len(w)):
    print(lambda_z(w[i], 0.001, z[i]))
# Out:
# (-0.2095976396315277+0.0002686403303149078j)
# (-0.05322999600526751+1.1351105076969146e-05j)
# (8.619096586337527e-06-7.322069903057749e-05j)
# (0.028980302853063522-0.00011645763004217548j)
# (0.03702839973691674-0.00013120769200187891j)
# (0.02739451539430604-0.0001379424784873906j)
# (-0.013566196245449191-0.00021865336524218293j)
# (0.13733438526247-0.003748005736842336j)
# (0.32538452522886274-0.002964643604342364j)
# (0.45805530117657334+0.0025612067600160344j)
